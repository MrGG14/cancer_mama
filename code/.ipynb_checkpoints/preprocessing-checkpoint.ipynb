# %%
import pandas as pd
import mysql.connector
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Datos sucios

# %%
patients_batch1 = pd.read_csv("../data/patients_batch1.csv")
patients_batch1
# Out:
#            ehr  birth_date diagnosis_date death_date
# 0     10011773  1959-07-05     2015-04-02        NaN
# 1     10020495  1953-10-02     2017-12-04        NaN
# 2     10030299  1966-08-16     2019-06-27        NaN
# 3     10030824  1953-03-03     2018-09-07        NaN
# 4     10041592  1959-07-06     2018-11-19        NaN
# ...        ...         ...            ...        ...
# 7495  77575810  1958-03-21     2014-02-22        NaN
# 7496  77578551  1948-05-18     2018-07-11        NaN
# 7497  77579212  1976-02-13     2022-03-22        NaN
# 7498  77605742  1950-03-16     2015-06-29        NaN
# 7499  77606485  1962-05-13     2013-11-26        NaN
#
# [7500 rows x 4 columns]

# %%
patients_batch2 = pd.read_csv("../data/patients_batch2.csv")
patients_batch2
# Out:
#            ehr  birth_date diagnosis_date  death_date
# 0     72992494  13/02/1942     08/05/2018         NaN
# 1     73002338  22/10/1949     08/09/2018         NaN
# 2     73008149  04/12/1969     12/04/2018         NaN
# 3     73012939  18/09/1973     17/04/2014  01/01/2018
# 4     73019870  07/12/1955     24/05/2018         NaN
# ...        ...         ...            ...         ...
# 2995  99966287  16/12/1978     02/08/2018         NaN
# 2996  99981192  10/04/1949     28/10/2017         NaN
# 2997  99988958  21/01/1966     27/05/2013         NaN
# 2998  99992350  04/09/1939     17/12/2018         NaN
# 2999  99994417  10/02/1962     01/04/2017         NaN
#
# [3000 rows x 4 columns]

# %%
gynecological = pd.read_excel("../data/gynecological.xlsx")
gynecological
# Out:
#       Unnamed: 0       ehr  pregnancy  birth  caesarean  abort  menarche_age  \
# 0              0  10011773       -8.0    0.0        NaN    0.0           NaN
# 1              1  10030299        3.0    NaN        0.0    0.0           NaN
# 2              2  10030824        0.0    0.0        0.0    NaN           NaN
# 3              3  10053435        2.0    NaN        0.0    1.0          21.0
# 4              4  10111454        0.0   -6.0        NaN    0.0          16.0
# ...          ...       ...        ...    ...        ...    ...           ...
# 7681        7681  99948591        9.0    2.0       -4.0    0.0          12.0
# 7682        7682  99961100        2.0    2.0        0.0    0.0          19.0
# 7683        7683  99981192        3.0    3.0        0.0   -5.0          11.0
# 7684        7684  99992350        4.0    3.0        NaN   -6.0          11.0
# 7685        7685  99994417        2.0   -6.0        NaN    NaN          13.0
#
#       menopause_age
# 0              71.0
# 1               NaN
# 2              44.0
# 3              74.0
# 4              55.0
# ...             ...
# 7681           47.0
# 7682           52.0
# 7683            NaN
# 7684           55.0
# 7685            NaN
#
# [7686 rows x 8 columns]

# %%
histochemistry = pd.read_json("../data/histochemistry.json")
histochemistry
# Out:
#            ehr   er  her2  ki67   pr
# 0     10011773  0.0   0.0  19.0  NaN
# 1     10020495  1.0   0.0   9.0  0.0
# 2     10030299  1.0   NaN  18.0  1.0
# 3     10030824  1.0   0.0   NaN  1.0
# 4     10041592  0.0   0.0  65.0  0.0
# ...        ...  ...   ...   ...  ...
# 9995  99966287  1.0   0.0   NaN  0.0
# 9996  99981192  1.0   0.0  14.0  0.0
# 9997  99988958  NaN   0.0  67.0  NaN
# 9998  99992350  0.0   0.0  16.0  0.0
# 9999  99994417  1.0   0.0  20.0  1.0
#
# [10000 rows x 5 columns]

# %%
if os.path.exists('../data/tumor.xlsx'):
    tumor = pd.read_excel("../data/tumor.xlsx")
else:
    config = {'host': "localhost",
              'port': 3306,
              'user': "cancer_mama_user",
              'passwd': "cancer_mama_password",
              'db': "cancer_mama"}
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()

    sql_columns_names = "SHOW COLUMNS from tumor;"
    sql_tumor = "SELECT * FROM tumor"

    cursor.execute(sql_tumor)
    tumor = pd.DataFrame(cursor.fetchall())

    cursor.execute(sql_columns_names)
    columns_names = pd.DataFrame(cursor.fetchall())

    cursor.close()
    conn.close()

    tumor = tumor.set_axis(columns_names[0], axis=1)
    tumor.to_excel("../data/tumor.xlsx")
tumor
# Out:
#        Unnamed: 0       ehr  n_tumor t_category  n_category  m_category  \
# 0               0  10011773        1         IS           0           0
# 1               1  10020495        1          1           0           0
# 2               2  10020495        2          3           1           0
# 3               3  10030299        1          1           0           0
# 4               4  10030824        1          2           1           0
# ...           ...       ...      ...        ...         ...         ...
# 11162       11162  99966287        1          1           1           0
# 11163       11163  99981192        1          1           0           0
# 11164       11164  99988958        1          0           2           0
# 11165       11165  99992350        1          2           0           0
# 11166       11166  99994417        1          0           0           0
#
#       t_category_after_neoadj  n_category_after_neoadj  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                           2                      0.0
# 3                         NaN                      NaN
# 4                           2                      2.0
# ...                       ...                      ...
# 11162                       1                      0.0
# 11163                     NaN                      NaN
# 11164                       1                      1.0
# 11165                       3                      2.0
# 11166                       1                      0.0
#
#        m_category_after_neoadj stage_diagnosis stage_after_neo  grade  ductal  \
# 0                          NaN               0             NaN      1     NaN
# 1                          NaN              IA             NaN      2     1.0
# 2                          NaN              IA             NaN      2     1.0
# 3                          NaN              IA             NaN      1     1.0
# 4                          0.0            IIIA            IIIA      3     NaN
# ...                        ...             ...             ...    ...     ...
# 11162                      0.0              IB             IIA      3     1.0
# 11163                      NaN              IA             NaN      2     NaN
# 11164                      0.0            IIIA             IIA      1     1.0
# 11165                      0.0             IIA            IIIA      2     1.0
# 11166                      0.0              IA              IA      3     NaN
#
#        lobular neoadjuvant
# 0          NaN          no
# 1          NaN          no
# 2          NaN         yes
# 3          NaN          no
# 4          1.0         yes
# ...        ...         ...
# 11162      NaN         yes
# 11163      NaN          no
# 11164      NaN         yes
# 11165      NaN         yes
# 11166      NaN         yes
#
# [11167 rows x 15 columns]

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## Patients

# %%
len(patients_batch1.ehr.unique())
# Out:
# 7500

# %%
len(patients_batch2.ehr.unique())
# Out:
# 3000

# %% [markdown]
# Vemos si hay algún paciente común en ambos batchs de datos de pacientes

# %%
any(patients_batch1['ehr'].isin(patients_batch2['ehr']))
# Out:
# True

# %% [markdown]
# Obtenemos los ids de los pacientes que aparecen en ambos

# %%
elementos_comunes = set(patients_batch1['ehr']).intersection(set(patients_batch2['ehr']))
print(f"El número total de pacientes comunes son: {len(elementos_comunes)}")
# Out:
# El número total de pacientes comunes son: 500

# %% [markdown]
# Vemos ahora si estos pacientes que aparecen en ambos documentos tienen valores distintos en cada uno de los documentos

# %%
pacientes_comunes_batch1 = patients_batch1[patients_batch1['ehr'].isin(elementos_comunes)]
pacientes_comunes_batch1
# Out:
#            ehr  birth_date diagnosis_date  death_date
# 7000  72992494  1942-02-13     2018-05-08         NaN
# 7001  73002338  1949-10-22     2018-09-08         NaN
# 7002  73008149  1969-12-04     2018-04-12         NaN
# 7003  73012939  1973-09-18     2014-04-17  2018-01-01
# 7004  73019870  1955-12-07     2018-05-24         NaN
# ...        ...         ...            ...         ...
# 7495  77575810  1958-03-21     2014-02-22         NaN
# 7496  77578551  1948-05-18     2018-07-11         NaN
# 7497  77579212  1976-02-13     2022-03-22         NaN
# 7498  77605742  1950-03-16     2015-06-29         NaN
# 7499  77606485  1962-05-13     2013-11-26         NaN
#
# [500 rows x 4 columns]

# %%
pacientes_comunes_batch2 = patients_batch2[patients_batch2['ehr'].isin(elementos_comunes)]
pacientes_comunes_batch2
# Out:
#           ehr  birth_date diagnosis_date  death_date
# 0    72992494  13/02/1942     08/05/2018         NaN
# 1    73002338  22/10/1949     08/09/2018         NaN
# 2    73008149  04/12/1969     12/04/2018         NaN
# 3    73012939  18/09/1973     17/04/2014  01/01/2018
# 4    73019870  07/12/1955     24/05/2018         NaN
# ..        ...         ...            ...         ...
# 495  77575810  21/03/1958     22/02/2014         NaN
# 496  77578551  18/05/1948     11/07/2018         NaN
# 497  77579212  13/02/1976     22/03/2022         NaN
# 498  77605742  16/03/1950     29/06/2015         NaN
# 499  77606485  13/05/1962     26/11/2013         NaN
#
# [500 rows x 4 columns]

# %% [markdown]
# Parece ser que los valores sí que son iguales, pero cada documento usa un formato distinto para las fechas. Vamos a ponerlo todo en el formato del primer documento, que es el formato por defecto de datetime: aaaa-mm-dd

# %%
pacientes_comunes_batch2['birth_date'] = pd.to_datetime(pacientes_comunes_batch2['birth_date'], format='%d/%m/%Y')
pacientes_comunes_batch2['death_date'] = pd.to_datetime(pacientes_comunes_batch2['death_date'], format='%d/%m/%Y')
pacientes_comunes_batch2['diagnosis_date'] = pd.to_datetime(pacientes_comunes_batch2['diagnosis_date'], format='%d/%m/%Y')

pacientes_comunes_batch1['birth_date'] = pd.to_datetime(pacientes_comunes_batch1['birth_date'])
pacientes_comunes_batch1['diagnosis_date'] = pd.to_datetime(pacientes_comunes_batch1['diagnosis_date'])
pacientes_comunes_batch1['death_date'] = pd.to_datetime(pacientes_comunes_batch1['death_date'])

pacientes_comunes_batch2
# Out:
#           ehr birth_date diagnosis_date death_date
# 0    72992494 1942-02-13     2018-05-08        NaT
# 1    73002338 1949-10-22     2018-09-08        NaT
# 2    73008149 1969-12-04     2018-04-12        NaT
# 3    73012939 1973-09-18     2014-04-17 2018-01-01
# 4    73019870 1955-12-07     2018-05-24        NaT
# ..        ...        ...            ...        ...
# 495  77575810 1958-03-21     2014-02-22        NaT
# 496  77578551 1948-05-18     2018-07-11        NaT
# 497  77579212 1976-02-13     2022-03-22        NaT
# 498  77605742 1950-03-16     2015-06-29        NaT
# 499  77606485 1962-05-13     2013-11-26        NaT
#
# [500 rows x 4 columns]

# %%
pacientes_comunes_batch1['birth_date'] = pd.to_datetime(pacientes_comunes_batch1['birth_date'])
pacientes_comunes_batch1['diagnosis_date'] = pd.to_datetime(pacientes_comunes_batch1['diagnosis_date'])
pacientes_comunes_batch1['death_date'] = pd.to_datetime(pacientes_comunes_batch1['death_date'])

# %%
pacientes_comunes_batch1.reset_index(drop=True, inplace=True)

# %%
pacientes_comunes_batch2.equals(pacientes_comunes_batch1)
# Out:
# True

# %% [markdown]
# Vemos que todos los valores de los pacientes que aparecen en los dos documentos son exactamente iguales

# %%
patients_batch1
# Out:
#            ehr  birth_date diagnosis_date death_date
# 0     10011773  1959-07-05     2015-04-02        NaN
# 1     10020495  1953-10-02     2017-12-04        NaN
# 2     10030299  1966-08-16     2019-06-27        NaN
# 3     10030824  1953-03-03     2018-09-07        NaN
# 4     10041592  1959-07-06     2018-11-19        NaN
# ...        ...         ...            ...        ...
# 7495  77575810  1958-03-21     2014-02-22        NaN
# 7496  77578551  1948-05-18     2018-07-11        NaN
# 7497  77579212  1976-02-13     2022-03-22        NaN
# 7498  77605742  1950-03-16     2015-06-29        NaN
# 7499  77606485  1962-05-13     2013-11-26        NaN
#
# [7500 rows x 4 columns]

# %%
patients_batch2
# Out:
#            ehr  birth_date diagnosis_date  death_date
# 0     72992494  13/02/1942     08/05/2018         NaN
# 1     73002338  22/10/1949     08/09/2018         NaN
# 2     73008149  04/12/1969     12/04/2018         NaN
# 3     73012939  18/09/1973     17/04/2014  01/01/2018
# 4     73019870  07/12/1955     24/05/2018         NaN
# ...        ...         ...            ...         ...
# 2995  99966287  16/12/1978     02/08/2018         NaN
# 2996  99981192  10/04/1949     28/10/2017         NaN
# 2997  99988958  21/01/1966     27/05/2013         NaN
# 2998  99992350  04/09/1939     17/12/2018         NaN
# 2999  99994417  10/02/1962     01/04/2017         NaN
#
# [3000 rows x 4 columns]

# %%
patients_batch2['birth_date'] = pd.to_datetime(patients_batch2['birth_date'], format='%d/%m/%Y')
patients_batch2['diagnosis_date'] = pd.to_datetime(patients_batch2['diagnosis_date'], format='%d/%m/%Y')
patients_batch2['birth_date'] = pd.to_datetime(patients_batch2['birth_date'], format='%d/%m/%Y')

patients_batch1['birth_date'] = pd.to_datetime(patients_batch1['birth_date'])
patients_batch1['diagnosis_date'] = pd.to_datetime(patients_batch1['diagnosis_date'])
patients_batch1['death_date'] = pd.to_datetime(patients_batch1['death_date'])

# %%
patients_batch1_sin_comunes = patients_batch1[~patients_batch1["ehr"].isin(pacientes_comunes_batch1["ehr"])]
patients_batch1_sin_comunes
# Out:
#            ehr birth_date diagnosis_date death_date
# 0     10011773 1959-07-05     2015-04-02        NaT
# 1     10020495 1953-10-02     2017-12-04        NaT
# 2     10030299 1966-08-16     2019-06-27        NaT
# 3     10030824 1953-03-03     2018-09-07        NaT
# 4     10041592 1959-07-06     2018-11-19        NaT
# ...        ...        ...            ...        ...
# 6995  72964107 1959-01-01     2019-12-18        NaT
# 6996  72975846 1959-07-02     2017-09-01        NaT
# 6997  72976171 1972-12-01     2018-06-09        NaT
# 6998  72983987 1962-08-28     2013-07-03 2019-01-25
# 6999  72990296 1975-11-20     2018-06-17        NaT
#
# [7000 rows x 4 columns]

# %%
patients = pd.concat([patients_batch1_sin_comunes, patients_batch2], ignore_index=True)
patients
# Out:
#            ehr birth_date diagnosis_date death_date
# 0     10011773 1959-07-05     2015-04-02        NaN
# 1     10020495 1953-10-02     2017-12-04        NaN
# 2     10030299 1966-08-16     2019-06-27        NaN
# 3     10030824 1953-03-03     2018-09-07        NaN
# 4     10041592 1959-07-06     2018-11-19        NaN
# ...        ...        ...            ...        ...
# 9995  99966287 1978-12-16     2018-08-02        NaN
# 9996  99981192 1949-04-10     2017-10-28        NaN
# 9997  99988958 1966-01-21     2013-05-27        NaN
# 9998  99992350 1939-09-04     2018-12-17        NaN
# 9999  99994417 1962-02-10     2017-04-01        NaN
#
# [10000 rows x 4 columns]

# %%
len(patients.ehr.unique())
# Out:
# 10000

# %% [markdown]
# ## Histochemistry

# %%
histochemistry
# Out:
#            ehr   er  her2  ki67   pr
# 0     10011773  0.0   0.0  19.0  NaN
# 1     10020495  1.0   0.0   9.0  0.0
# 2     10030299  1.0   NaN  18.0  1.0
# 3     10030824  1.0   0.0   NaN  1.0
# 4     10041592  0.0   0.0  65.0  0.0
# ...        ...  ...   ...   ...  ...
# 9995  99966287  1.0   0.0   NaN  0.0
# 9996  99981192  1.0   0.0  14.0  0.0
# 9997  99988958  NaN   0.0  67.0  NaN
# 9998  99992350  0.0   0.0  16.0  0.0
# 9999  99994417  1.0   0.0  20.0  1.0
#
# [10000 rows x 5 columns]

# %%
len(histochemistry.ehr.unique())
# Out:
# 10000

# %% [markdown]
# Coinciden todos los ids con los de patients

# %%
elementos_comunes = set(histochemistry['ehr']).intersection(set(patients['ehr']))
len(elementos_comunes)
# Out:
# 10000

# %% [markdown]
# Como comparten todos los ids simplemente añadimos la informacion del nuevo df al de 'patients'

# %%
patients = pd.merge(histochemistry, patients, on='ehr')

# %%
patients
# Out:
#            ehr   er  her2  ki67   pr birth_date diagnosis_date death_date
# 0     10011773  0.0   0.0  19.0  NaN 1959-07-05     2015-04-02        NaN
# 1     10020495  1.0   0.0   9.0  0.0 1953-10-02     2017-12-04        NaN
# 2     10030299  1.0   NaN  18.0  1.0 1966-08-16     2019-06-27        NaN
# 3     10030824  1.0   0.0   NaN  1.0 1953-03-03     2018-09-07        NaN
# 4     10041592  0.0   0.0  65.0  0.0 1959-07-06     2018-11-19        NaN
# ...        ...  ...   ...   ...  ...        ...            ...        ...
# 9995  99966287  1.0   0.0   NaN  0.0 1978-12-16     2018-08-02        NaN
# 9996  99981192  1.0   0.0  14.0  0.0 1949-04-10     2017-10-28        NaN
# 9997  99988958  NaN   0.0  67.0  NaN 1966-01-21     2013-05-27        NaN
# 9998  99992350  0.0   0.0  16.0  0.0 1939-09-04     2018-12-17        NaN
# 9999  99994417  1.0   0.0  20.0  1.0 1962-02-10     2017-04-01        NaN
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Gynecological

# %%
gynecological
# Out:
#       Unnamed: 0       ehr  pregnancy  birth  caesarean  abort  menarche_age  \
# 0              0  10011773       -8.0    0.0        NaN    0.0           NaN
# 1              1  10030299        3.0    NaN        0.0    0.0           NaN
# 2              2  10030824        0.0    0.0        0.0    NaN           NaN
# 3              3  10053435        2.0    NaN        0.0    1.0          21.0
# 4              4  10111454        0.0   -6.0        NaN    0.0          16.0
# ...          ...       ...        ...    ...        ...    ...           ...
# 7681        7681  99948591        9.0    2.0       -4.0    0.0          12.0
# 7682        7682  99961100        2.0    2.0        0.0    0.0          19.0
# 7683        7683  99981192        3.0    3.0        0.0   -5.0          11.0
# 7684        7684  99992350        4.0    3.0        NaN   -6.0          11.0
# 7685        7685  99994417        2.0   -6.0        NaN    NaN          13.0
#
#       menopause_age
# 0              71.0
# 1               NaN
# 2              44.0
# 3              74.0
# 4              55.0
# ...             ...
# 7681           47.0
# 7682           52.0
# 7683            NaN
# 7684           55.0
# 7685            NaN
#
# [7686 rows x 8 columns]

# %%
gynecological.drop(columns=['Unnamed: 0'], inplace=True)

# %%
len(gynecological.ehr.unique())
# Out:
# 7686

# %%
elementos_comunes = set(gynecological['ehr']).intersection(set(patients['ehr']))
len(elementos_comunes)
# Out:
# 7686

# %%
gynecological_patients = pd.merge(gynecological, patients, on='ehr')

# %%
gynecological_patients
# Out:
#            ehr  pregnancy  birth  caesarean  abort  menarche_age  \
# 0     10011773       -8.0    0.0        NaN    0.0           NaN
# 1     10030299        3.0    NaN        0.0    0.0           NaN
# 2     10030824        0.0    0.0        0.0    NaN           NaN
# 3     10053435        2.0    NaN        0.0    1.0          21.0
# 4     10111454        0.0   -6.0        NaN    0.0          16.0
# ...        ...        ...    ...        ...    ...           ...
# 7681  99948591        9.0    2.0       -4.0    0.0          12.0
# 7682  99961100        2.0    2.0        0.0    0.0          19.0
# 7683  99981192        3.0    3.0        0.0   -5.0          11.0
# 7684  99992350        4.0    3.0        NaN   -6.0          11.0
# 7685  99994417        2.0   -6.0        NaN    NaN          13.0
#
#       menopause_age   er  her2  ki67   pr birth_date diagnosis_date death_date
# 0              71.0  0.0   0.0  19.0  NaN 1959-07-05     2015-04-02        NaN
# 1               NaN  1.0   NaN  18.0  1.0 1966-08-16     2019-06-27        NaN
# 2              44.0  1.0   0.0   NaN  1.0 1953-03-03     2018-09-07        NaN
# 3              74.0  1.0   0.0   NaN  1.0 1957-08-05     2017-12-01        NaN
# 4              55.0  1.0   0.0  72.0  1.0 1961-04-02     2017-06-15        NaN
# ...             ...  ...   ...   ...  ...        ...            ...        ...
# 7681           47.0  1.0   0.0  12.0  1.0 1955-01-08     2022-02-26        NaN
# 7682           52.0  1.0   0.0  21.0  1.0 1970-09-24     2018-01-04        NaN
# 7683            NaN  1.0   0.0  14.0  0.0 1949-04-10     2017-10-28        NaN
# 7684           55.0  0.0   0.0  16.0  0.0 1939-09-04     2018-12-17        NaN
# 7685            NaN  1.0   0.0  20.0  1.0 1962-02-10     2017-04-01        NaN
#
# [7686 rows x 14 columns]

# %% [markdown]
# ## Tumor

# %%
tumor
# Out:
#        Unnamed: 0       ehr  n_tumor t_category  n_category  m_category  \
# 0               0  10011773        1         IS           0           0
# 1               1  10020495        1          1           0           0
# 2               2  10020495        2          3           1           0
# 3               3  10030299        1          1           0           0
# 4               4  10030824        1          2           1           0
# ...           ...       ...      ...        ...         ...         ...
# 11162       11162  99966287        1          1           1           0
# 11163       11163  99981192        1          1           0           0
# 11164       11164  99988958        1          0           2           0
# 11165       11165  99992350        1          2           0           0
# 11166       11166  99994417        1          0           0           0
#
#       t_category_after_neoadj  n_category_after_neoadj  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                           2                      0.0
# 3                         NaN                      NaN
# 4                           2                      2.0
# ...                       ...                      ...
# 11162                       1                      0.0
# 11163                     NaN                      NaN
# 11164                       1                      1.0
# 11165                       3                      2.0
# 11166                       1                      0.0
#
#        m_category_after_neoadj stage_diagnosis stage_after_neo  grade  ductal  \
# 0                          NaN               0             NaN      1     NaN
# 1                          NaN              IA             NaN      2     1.0
# 2                          NaN              IA             NaN      2     1.0
# 3                          NaN              IA             NaN      1     1.0
# 4                          0.0            IIIA            IIIA      3     NaN
# ...                        ...             ...             ...    ...     ...
# 11162                      0.0              IB             IIA      3     1.0
# 11163                      NaN              IA             NaN      2     NaN
# 11164                      0.0            IIIA             IIA      1     1.0
# 11165                      0.0             IIA            IIIA      2     1.0
# 11166                      0.0              IA              IA      3     NaN
#
#        lobular neoadjuvant
# 0          NaN          no
# 1          NaN          no
# 2          NaN         yes
# 3          NaN          no
# 4          1.0         yes
# ...        ...         ...
# 11162      NaN         yes
# 11163      NaN          no
# 11164      NaN         yes
# 11165      NaN         yes
# 11166      NaN         yes
#
# [11167 rows x 15 columns]

# %%
tumor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# hay ids que se repiten. una persona puede tener varios tumores

# %%
len(tumor.ehr.unique())
# Out:
# 9971

# %%
elementos_comunes = set(tumor['ehr']).intersection(set(gynecological_patients['ehr']))
len(elementos_comunes)
# Out:
# 7666

# %% [markdown]
# Tiene mas elementos en comun con 'patients' que con 'gynecological_patients'

# %%
elementos_comunes = set(tumor['ehr']).intersection(set(patients['ehr']))
len(elementos_comunes)
# Out:
# 9971

# %%
tumor_patients = pd.merge(tumor, patients, on='ehr')

# %% [markdown]
# Finalmente obtenemos un df en el que se incluye la informacion de todos los pasados salvo 'gynecological'. Sin embargo en este df no hay una unica fila por cada paciente, sino que puede haber varias debido a que un paciente puede tener varios tumores, dando lugar a una duplicidad parcial de filas

# %%
tumor_patients
# Out:
#             ehr  n_tumor t_category  n_category  m_category  \
# 0      10011773        1         IS           0           0
# 1      10020495        1          1           0           0
# 2      10020495        2          3           1           0
# 3      10030299        1          1           0           0
# 4      10030824        1          2           1           0
# ...         ...      ...        ...         ...         ...
# 11162  99966287        1          1           1           0
# 11163  99981192        1          1           0           0
# 11164  99988958        1          0           2           0
# 11165  99992350        1          2           0           0
# 11166  99994417        1          0           0           0
#
#       t_category_after_neoadj  n_category_after_neoadj  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                           2                      0.0
# 3                         NaN                      NaN
# 4                           2                      2.0
# ...                       ...                      ...
# 11162                       1                      0.0
# 11163                     NaN                      NaN
# 11164                       1                      1.0
# 11165                       3                      2.0
# 11166                       1                      0.0
#
#        m_category_after_neoadj stage_diagnosis stage_after_neo  ...  ductal  \
# 0                          NaN               0             NaN  ...     NaN
# 1                          NaN              IA             NaN  ...     1.0
# 2                          NaN              IA             NaN  ...     1.0
# 3                          NaN              IA             NaN  ...     1.0
# 4                          0.0            IIIA            IIIA  ...     NaN
# ...                        ...             ...             ...  ...     ...
# 11162                      0.0              IB             IIA  ...     1.0
# 11163                      NaN              IA             NaN  ...     NaN
# 11164                      0.0            IIIA             IIA  ...     1.0
# 11165                      0.0             IIA            IIIA  ...     1.0
# 11166                      0.0              IA              IA  ...     NaN
#
#        lobular  neoadjuvant   er  her2  ki67   pr  birth_date diagnosis_date  \
# 0          NaN           no  0.0   0.0  19.0  NaN  1959-07-05     2015-04-02
# 1          NaN           no  1.0   0.0   9.0  0.0  1953-10-02     2017-12-04
# 2          NaN          yes  1.0   0.0   9.0  0.0  1953-10-02     2017-12-04
# 3          NaN           no  1.0   NaN  18.0  1.0  1966-08-16     2019-06-27
# 4          1.0          yes  1.0   0.0   NaN  1.0  1953-03-03     2018-09-07
# ...        ...          ...  ...   ...   ...  ...         ...            ...
# 11162      NaN          yes  1.0   0.0   NaN  0.0  1978-12-16     2018-08-02
# 11163      NaN           no  1.0   0.0  14.0  0.0  1949-04-10     2017-10-28
# 11164      NaN          yes  NaN   0.0  67.0  NaN  1966-01-21     2013-05-27
# 11165      NaN          yes  0.0   0.0  16.0  0.0  1939-09-04     2018-12-17
# 11166      NaN          yes  1.0   0.0  20.0  1.0  1962-02-10     2017-04-01
#
#       death_date
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 11162        NaN
# 11163        NaN
# 11164        NaN
# 11165        NaN
# 11166        NaN
#
# [11167 rows x 21 columns]

# %%
len(tumor_patients.ehr.unique())
# Out:
# 9971

# %% [markdown]
# Creamos tambien un df mas reducido pero que sí disponga de los datos de 'gynecological'

# %%
tumor_patients_gyn = pd.merge(tumor, gynecological_patients, on='ehr')

# %%
tumor_patients_gyn
# Out:
#            ehr  n_tumor t_category  n_category  m_category  \
# 0     10011773        1         IS           0           0
# 1     10030299        1          1           0           0
# 2     10030824        1          2           1           0
# 3     10053435        1          0           0           0
# 4     10111454        1          1           0           0
# ...        ...      ...        ...         ...         ...
# 8599  99948591        1          2           0           0
# 8600  99961100        1          1           2           0
# 8601  99981192        1          1           0           0
# 8602  99992350        1          2           0           0
# 8603  99994417        1          0           0           0
#
#      t_category_after_neoadj  n_category_after_neoadj  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                          2                      2.0
# 3                        NaN                      NaN
# 4                          1                      0.0
# ...                      ...                      ...
# 8599                     NaN                      NaN
# 8600                       1                      0.0
# 8601                     NaN                      NaN
# 8602                       3                      2.0
# 8603                       1                      0.0
#
#       m_category_after_neoadj stage_diagnosis stage_after_neo  ...  abort  \
# 0                         NaN               0             NaN  ...    0.0
# 1                         NaN              IA             NaN  ...    0.0
# 2                         0.0            IIIA            IIIA  ...    NaN
# 3                         NaN              IV             NaN  ...    1.0
# 4                         0.0              IA              IA  ...    0.0
# ...                       ...             ...             ...  ...    ...
# 8599                      NaN             IIA             NaN  ...    0.0
# 8600                      0.0             IIA              IB  ...    0.0
# 8601                      NaN              IA             NaN  ...   -5.0
# 8602                      0.0             IIA            IIIA  ...   -6.0
# 8603                      0.0              IA              IA  ...    NaN
#
#       menarche_age  menopause_age   er  her2  ki67   pr  birth_date  \
# 0              NaN           71.0  0.0   0.0  19.0  NaN  1959-07-05
# 1              NaN            NaN  1.0   NaN  18.0  1.0  1966-08-16
# 2              NaN           44.0  1.0   0.0   NaN  1.0  1953-03-03
# 3             21.0           74.0  1.0   0.0   NaN  1.0  1957-08-05
# 4             16.0           55.0  1.0   0.0  72.0  1.0  1961-04-02
# ...            ...            ...  ...   ...   ...  ...         ...
# 8599          12.0           47.0  1.0   0.0  12.0  1.0  1955-01-08
# 8600          19.0           52.0  1.0   0.0  21.0  1.0  1970-09-24
# 8601          11.0            NaN  1.0   0.0  14.0  0.0  1949-04-10
# 8602          11.0           55.0  0.0   0.0  16.0  0.0  1939-09-04
# 8603          13.0            NaN  1.0   0.0  20.0  1.0  1962-02-10
#
#       diagnosis_date  death_date
# 0         2015-04-02         NaN
# 1         2019-06-27         NaN
# 2         2018-09-07         NaN
# 3         2017-12-01         NaN
# 4         2017-06-15         NaN
# ...              ...         ...
# 8599      2022-02-26         NaN
# 8600      2018-01-04         NaN
# 8601      2017-10-28         NaN
# 8602      2018-12-17         NaN
# 8603      2017-04-01         NaN
#
# [8604 rows x 27 columns]
